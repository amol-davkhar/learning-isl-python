# %% [markdown]
# # Chapter 2 Exercises

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
np.set_printoptions(precision=2)

# %%
College = pd.read_csv("../data-sets/College.csv")
College
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %%
test =pd.read_csv("../data-sets/College.csv",index_col=0)
test
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
college_updated = College.rename({'Unnamed: 0': 'College'}, axis=1)
college_updated = college_updated.set_index('College')
college_updated
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
College =college_updated
College
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
College.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
cols = ['Top10perc','Apps','Enroll']
pd.plotting.scatter_matrix(College[cols]);

# %%
fig, axes = plt.subplots(ncols=2,figsize=(12,12))
College.boxplot('Outstate',by='Private',ax=axes[0])
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Private'>

# %%
College['Elite']= pd.cut(College['Top10perc'],[0,50,100],labels=['No','Yes']) #binning the column of 'Top10perc' into two bins
#bleow 50% and above it 0->0.5 0.5->1

# %%
College['Elite'].value_counts()
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %%
fig, axes = plt.subplots(ncols=3,figsize=(12,12))

College.plot.hist(column="Grad.Rate",by="Elite",ax=axes[2]);
# Out:
# /tmp/ipykernel_82577/843951226.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   College.plot.hist(column="Grad.Rate",by="Elite",ax=axes[2]);
# /tmp/ipykernel_82577/843951226.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   College.plot.hist(column="Grad.Rate",by="Elite",ax=axes[2]);
# /tmp/ipykernel_82577/843951226.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# ...

# %%
College['Acceptence_perc']=College['Accept']/College['Apps']

# %%
College['Acceptence_perc']=College['Acceptence_perc']*100

# %%
College['Acceptence_perc'].describe()
# Out:
# count    777.000000
# mean      74.692771
# std       14.710392
# min       15.448631
# 25%       67.564745
# 50%       77.875000
# 75%       84.852217
# max      100.000000
# Name: Acceptence_perc, dtype: float64

# %%
College.loc[lambda df:(df['Elite']=='No')&(df['Grad.Rate']>80),['Acceptence_perc']]
# Out:
#                                  Acceptence_perc
# College
# Assumption College                     79.625293
# Baldwin-Wallace College                80.828402
# Bellarmine College                     87.608426
# Bentley College                        67.224466
# Bradley University                     90.629148
# ...                                          ...
# Westmont College                       75.052632
# Wingate College                        82.082324
# Worcester Polytechnic Institute        83.598266
# Xavier University                      92.138846
# York College of Pennsylvania           62.060890
#
# [109 rows x 1 columns]
